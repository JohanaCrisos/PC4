# %%
import pandas as pd

fragilityCiaLink="https://github.com/CienciaDeDatosEspacial/merging/raw/main/FragilityCia_isos.csv"
fragilityCia=pd.read_csv(fragilityCiaLink)

fragilityCia.head()
# Out:
#                Country                            Officialstatename  \
# 0          AFGHANISTAN          The Islamic Republic of Afghanistan
# 1              ALBANIA                      The Republic of Albania
# 2              ALGERIA  The People's Democratic Republic of Algeria
# 3               ANGOLA                       The Republic of Angola
# 4  ANTIGUA AND BARBUDA                          Antigua and Barbuda
#
#   InternetccTLD iso2 iso3  fragility          co2  \
# 0           .af   AF  AFG      105.0    7893000.0
# 1           .al   AL  ALB       58.9    3794000.0
# 2           .dz   DZ  DZA       75.4  151633000.0
# 3           .ao   AO  AGO       87.8   19362000.0
# 4           .ag   AG  ATG       54.4     729000.0
#
#                               region  ForestRev_gdp
# 0                         SOUTH ASIA           0.20
# 1                             EUROPE           0.18
# 2                             AFRICA           0.10
# ...

# %%
fragilityCia[fragilityCia['Country'] == "MEXICO"]
# Out:
#     Country          Officialstatename InternetccTLD iso2 iso3  fragility  \
# 104  MEXICO  The United Mexican States           .mx   MX  MEX       69.7
#
#              co2         region  ForestRev_gdp
# 104  463739000.0  NORTH AMERICA            0.1

# %%
import os, geopandas as gpd
shapefile_pais = "/content/drive/My Drive/SHAPEFILE/contdv250kgw/contdv250kgw.shp"
mexico=gpd.read_file(shapefile_pais)

# %%
mexico.head()
#solo tenemos infirmación sobre la superficie
# Out:
#          AREA   PERIMETER  COV_  COV_ID  \
# 0  172.862069  282.395149     2       1
# 1    0.000045    0.032974     3       2
# 2    0.000004    0.008557     4       3
# 3    0.000012    0.021595     5       4
# 4    0.000140    0.073219     6       5
#
#                                             geometry
# 0  POLYGON ((-117.11734 32.46267, -117.11742 32.4...
# 1  POLYGON ((-117.29441 32.43412, -117.29514 32.4...
# 2  POLYGON ((-117.26293 32.42339, -117.2632 32.42...
# 3  POLYGON ((-117.25951 32.4148, -117.25991 32.41...
# 4  POLYGON ((-117.23958 32.39076, -117.23998 32.3...

# %%
# !pip install thefuzz
